# %%
from google.colab import drive
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/combined_output.txt'
with open(file_path, 'r', encoding='utf-8') as f:
    content = f.read()
content


text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_text(content)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from mcp.types import Prompt
from langchain_anthropic import ChatAnthropic
from google.colab import userdata
from langchain.tools import tool
api_key = userdata.get('OPENAI_API_KEY')
os.environ["ANTHROPIC_API_KEY"] = api_key
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langgraph.prebuilt import create_react_agent

agent_path = '/content/drive/MyDrive/agent.md'
with open(agent_path, 'r', encoding='utf-8') as f:
    agent_instructions = f.read()

llm = ChatAnthropic(
    model="claude-sonnet-4-6",
    temperature=0.7
)
prompt = ChatPromptTemplate.from_messages([
    ("system", agent_instructions),
    ("system", "Here are examples:\n" + reference),
    MessagesPlaceholder("chat_history"),
    ("human", "{input}"),
    MessagesPlaceholder("agent_scratchpad"),
])
tools = []
chat_history = [
    ("human", "Hello modernise legacy architecture"),
    ("ai", "Referencing like this :https://medium.com/cloud-journey-optimization/bridging-the-chasm-between-cloud-native-and-the-mainframe-b87a2ed77742")

]

agent = create_react_agent(
    model=llm,
    tools=[],
    prompt=agent_instructions
   )



response=agent.invoke({"messages": [
        ("user", "Hello modernise legacy architecture"),
        ("assistant", "Referencing like this :https://medium.com/cloud-journey-optimization/bridging-the-chasm-between-cloud-native-and-the-mainframe-b87a2ed77742"),
        ("user", "Can you generate modern architecture with input{chunks}")
    ]})
print(response)
with open("architecture.puml","w") as f:
    f.write(str(response))
# Out:
# /tmp/ipykernel_9327/2558670842.py:33: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(
# {'messages': [HumanMessage(content='Hello modernise legacy architecture', additional_kwargs={}, response_metadata={}, id='b6731dce-3838-4283-a579-fa558e7676e0'), AIMessage(content='Referencing like this :https://medium.com/cloud-journey-optimization/bridging-the-chasm-between-cloud-native-and-the-mainframe-b87a2ed77742', additional_kwargs={}, response_metadata={}, id='a77c20ca-cd03-4ce6-b5ae-875bc87da69e', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Can you generate modern architecture with input{chunks}', additional_kwargs={}, response_metadata={}, id='b7e89ee7-7b49-4f5b-ae8f-43a604e85429'), AIMessage(content='# Modern Architecture for Cash Account COBOL Modernization\n\nLet me first search the repository to understand the current state.\n\n## Current State Analysis\n\nBased on the mind map, the legacy system consists of:\n- **COBOL** business logic (Account processing, Validation, Workflows)\n- **DB2 for z/OS** persistence\n- **VSAM** caching\n- **CICS** transaction processing\n- **JCL** batch jobs\n- **Copybooks** for data structures\n\n---\n\n## Target Modern Architecture\n\n```plantuml\n@startuml Cash Account Modernization Architecture\n\n!define RECTANGLE class\n\nskinparam backgroundColor #FEFEFE\nskinparam component {\n    BackgroundColor #E8F4FD\n    BorderColor #2980B9\n    FontColor #2C3E50\n}\n\nskinparam database {\n    BackgroundColor #FDEBD0\n    BorderColor #E67E22\n}\n\nskinparam cloud {\n    BackgroundColor #EBF5FB\n    BorderColor #1ABC9C\n}\n\ntitle Cash Account - Modern Cloud Native Architecture\n\n\'============ INPUT LAYER ============\npackage "Input Layer [{chunks}]" #LightYellow {\n    component [REST API Chunks] as REST\n    component [Event Stream Chunks] as STREAM\n    component [Batch File Chunks] as BATCH\n    component [gRPC Chunks] as GRPC\n}\n\n\'============ API GATEWAY ============\npackage "API Gateway Layer" #LightBlue {\n    component [Kong / AWS API Gateway] as APIGW\n    component [Rate Limiter] as RATE\n    component [Auth - OAuth2/JWT] as AUTH\n}\n\n\'============ MICROSERVICES ============\npackage "Microservices Layer" #LightGreen {\n\n    package "Account Service\\n(Replaces COBOL Account Processing)" {\n        component [Account Controller] as AC\n        component [Account Business Logic] as ABL\n        component [Account Validator] as AV\n    }\n\n    package "Transaction Service\\n(Replaces CICS Transactions)" {\n        component [Transaction Controller] as TC\n        component [Transaction Processor] as TP\n        component [Transaction Validator] as TV\n    }\n\n    package "Workflow Service\\n(Replaces JCL Batch Jobs)" {\n        component [Workflow Orchestrator] as WO\n        component [Batch Processor] as BP\n        component [Job Scheduler] as JS\n    }\n\n    package "Validation Service\\n(Replaces COBOL Validation)" {\n        component [Rules Engine] as RE\n        component [Schema Validator] as SV\n    }\n}\n\n\'============ MESSAGING ============\npackage "Event Streaming Layer\\n(Replaces VSAM Caching)" #LightPink {\n    component [Apache Kafka] as KAFKA\n    component [Event Bus] as EB\n    component [Dead Letter Queue] as DLQ\n}\n\n\'============ CACHE ============\npackage "Caching Layer\\n(Replaces VSAM)" #Lavender {\n    database "Redis Cache" as REDIS\n    component [Cache Manager] as CM\n}\n\n\'============ PERSISTENCE ============\npackage "Persistence Layer\\n(Replaces DB2 z/OS)" #Wheat {\n    database "PostgreSQL\\n(Primary)" as PG\n    database "MongoDB\\n(Documents)" as MONGO\n    database "Data Warehouse\\n(Snowflake)" as DW\n}\n\n\'============ OBSERVABILITY ============\npackage "Observability Layer" #MistyRose {\n    component [Prometheus + Grafana] as PROM\n    component [ELK Stack] as ELK\n    component [Jaeger Tracing] as JAEGER\n    component [PagerDuty Alerts] as PAGER\n}\n\n\'============ INFRASTRUCTURE ============\npackage "Infrastructure Layer" #Honeydew {\n    component [Kubernetes (EKS/GKE)] as K8S\n    component [ ...

# %%
# !pip install langchain-anthropic
# Out:
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-1.4.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting anthropic<1.0.0,>=0.96.0 (from langchain-anthropic)
#   Downloading anthropic-0.97.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-core<2.0.0,>=1.3.2 (from langchain-anthropic)
#   Downloading langchain_core-1.3.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-anthropic) (2.12.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (0.14.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (1.33)
# Collecting langchain-protocol>=0.0.10 (from langchain-core<2.0.0,>=1.3.2->langchain-anthropic)
#   Downloading langchain_protocol-0.0.14-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (0.7.34)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (26.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (0.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-anthropic) (2.5.0)
# Downloading langchain_anthropic-1.4.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.4 MB/s eta 0:00:00
# Downloading anthropic-0.97.0-py3-none-any.whl (662 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.1/662.1 kB 29.3 MB/s eta 0:00:00
# Downloading langchain_core-1.3.2-py3-none-any.whl (542 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.4/542.4 kB 31.3 MB/s eta 0:00:00
# Downloading langchain_protocol-0.0.14-py3-none-any.whl (7.0 kB)
# Installing collected packages: langchain-protocol, anthropic, langchain-core, langchain-anthropic
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.3.1
#     Uninstalling langchain-core-1.3.1:
#       Successfully uninstalled langchain-core-1.3.1
# Successfully installed anthropic-0.97.0 langchain-anthropic-1.4.2 langchain-core-1.3.2 langchain-protocol-0.0.14

# %%
# !pip show langchain langgraph
# Out:
# Name: langchain
# Version: 1.2.15
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# ---
# Name: langgraph
# Version: 1.1.9
# Summary: Building stateful, multi-actor applications with LLMs
# Home-page: https://docs.langchain.com/oss/python/langgraph/overview
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph-sdk, pydantic, xxhash
# Required-by: langchain
